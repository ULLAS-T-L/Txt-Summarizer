# %% [markdown]
# <a href="https://colab.research.google.com/github/ULLAS-T-L/Txt-Summarizer/blob/main/Txtsummarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ULLAS-T-L/Txt-Summarizer.git
# Out:
# fatal: destination path 'Txt-Summarizer' already exists and is not an empty directory.

# %%
ls
# Out:
# sample_data/  Txt-Summarizer/

# %%
# %cd Txt-Summarizer

# !python main.py
# Out:
# /content/Txt-Summarizer
# Traceback (most recent call last):
#   File "/content/Txt-Summarizer/main.py", line 1, in <module>
#     from textSummarization.pipeline.stage_01_data_ingestion import DataIngestionTrainingPipeline
# ModuleNotFoundError: No module named 'textSummarization'

# %%
# !cd /content/Txt-Summarizer/src

# %%
ls
# Out:
# sample_data/  Txt-Summarizer/

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/Txt-Summarizer (from -r requirements.txt (line 21))
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 54.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 47.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 18.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 8.6 MB/s eta 0:00:00
# ...

# %%
# !python main.py
# Out:
# [2023-10-26 20:31:49,182: INFO: utils: NumExpr defaulting to 2 threads.]
# 2023-10-26 20:31:54.344349: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-26 20:31:54.344406: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-26 20:31:54.344445: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-26 20:31:56.121276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2023-10-26 20:31:57,007: INFO: main: >>>>>> stage Data Ingestion stage started <<<<<<]
# ...

# %%
# !pip install transformers[torch]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 9.5 MB/s eta 0:00:00
# ...

# %%
ls
# Out:
# app.py      config/     LICENSE  main.py      README.md         research/  src/
# artifacts/  dockerfile  logs/    params.yaml  requirements.txt  setup.py   template.py

# %%
# !git add .

# %%
# !git commit -m "model_tained"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@53e73520259a.(none)')

# %%
# !git config --global user.email "ullastl@gmail.com"

# %%
! git config --global user.name "ULLAS-T-L"

# %%
# !git commit -m "model_tained"
# Out:
# [main 452c003] model_tained
#  25 files changed, 548986 insertions(+), 162379 deletions(-)
#  create mode 100644 artifacts/data_ingestion/samsum_dataset/test/cache-a3315d977d80c441.arrow
#  create mode 100644 artifacts/data_ingestion/samsum_dataset/test/cache-c941e13647412609.arrow
#  create mode 100644 artifacts/data_ingestion/samsum_dataset/train/cache-7f7ed706e3cd6788.arrow
#  create mode 100644 artifacts/data_ingestion/samsum_dataset/validation/cache-9eef05aea875ff8b.arrow
#  create mode 100644 artifacts/model_trainer/pegasus-samsum-model/config.json
#  create mode 100644 artifacts/model_trainer/pegasus-samsum-model/generation_config.json
#  create mode 100644 artifacts/model_trainer/pegasus-samsum-model/pytorch_model.bin
#  create mode 100644 artifacts/model_trainer/runs/Oct26_20-32-17_7a0e907c5c12/events.out.tfevents.1698352337.7a0e907c5c12.3584.0
#  create mode 100644 artifacts/model_trainer/tokenizer/special_tokens_map.json
# ...

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git push origin main --set-upstream "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"
# Out:
# error: src refspec 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 does not match any
# error: failed to push some refs to 'https://github.com/ULLAS-T-L/Txt-Summarizer.git'
